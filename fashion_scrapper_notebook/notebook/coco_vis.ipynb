# %%
#keypoints_val_information.json -> 
#

# %%
from pathlib import Path
import os
from pycocotools.coco import COCO

# %%
base_dir = r'F:\workspace\datasets\DeepFashion2 Dataset'
ds_split = "train"
annFile = Path(base_dir) / ds_split /(ds_split + "_coco.json")

# Initialize the COCO api for instance annotations
coco=COCO(annFile)

# Load the categories in a variable
catIDs = coco.getCatIds()
cats = coco.loadCats(catIDs)

print(cats)
# Out:
# loading annotations into memory...
# Done (t=68.65s)
# creating index...
# index created!
# ...

# %%
cat_ids = coco.getCatIds()

# %%
imgs = list(coco.imgs.values())
img = imgs[0]

# %%
img
# Out:
# {'coco_url': '',
#  'date_captured': '',
#  'file_name': '000001.jpg',
#  'flickr_url': '',
#  'id': 1,
#  'license': 0,
#  'width': 468,
#  'height': 624}

# %%
anns_ids = coco.getAnnIds(imgIds=img['id'], catIds=cat_ids, iscrowd=False)
anns = coco.loadAnns(anns_ids)

# %%
anns_ids
# Out:
# [1, 2]

# %%
mask = coco.annToMask(anns[0])
for i in range(len(anns)):
    print(i)
    mask += coco.annToMask(anns[i])
# Out:
# 0
# 1

# %%
d = defaultdict(lambda: 0)

# %%
for x in mask:
    for y in x:
        d[y]+=1

# %%
d
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {0: 110095, 1: 154962, 2: 7107, 3: 19868})
